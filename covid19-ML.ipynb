# %%
# !pip install vega

# %%
# !pip install altair vega_datasets
# Out:
# ...
#   Using cached altair-4.1.0-py3-none-any.whl (727 kB)
# ...
#   Using cached vega_datasets-0.9.0-py3-none-any.whl (210 kB)
# ...

# %%
import numpy as np
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
df = pd.read_csv("C:\Python\COVID-19-time-series-clean-complete.csv")

# %%
df_new = df[df['Date'] == '2020-11-20'] 
df_new.head()
# Out:
#        Unnamed: 0        Date Country/Region  Confirmed  Deaths  Recovered  \
# 57267       57267  2020-11-20    Afghanistan      44443    1661    35370.0
# 57268       57268  2020-11-20        Albania      31459     672    15055.0
# 57269       57269  2020-11-20        Algeria      72755    2236    47581.0
# 57270       57270  2020-11-20        Andorra       6142      76     5239.0
# 57271       57271  2020-11-20         Angola      14267     334     7117.0
#
#         Active  New cases  New deaths  New recovered
# 57267   7412.0        215          11             20
# 57268  15732.0        836          15            490
# 57269  22938.0       1103          12            619
# 57270    827.0         76           0            112
# 57271   6816.0        133           1             55

# %%
order = df_new.sort_values('Confirmed',ascending=False)
new_order=order['Country/Region'].head(10)
nlist = new_order.values.tolist()
print(nlist)
# Out:
# ['US', 'India', 'Brazil', 'France', 'Russia', 'Spain', 'United Kingdom', 'Argentina', 'Italy', 'Colombia']

# %%
import pandas as pd
import altair as alt
full_grouped = pd.read_csv('C:\Python\COVID-19-time-series-clean-complete.csv', parse_dates=['Date'])
countries = nlist
selected_countries = full_grouped[full_grouped['Country/Region'].isin(countries)]
alt.Chart(selected_countries).mark_circle().encode(
    x='monthdate(Date):O',
    y='Country/Region',
    color='Country/Region',
    size=alt.Size('New cases:Q',
        scale=alt.Scale(range=[0, 1000]),
        legend=alt.Legend(title='Daily new cases')
    
    
    ) 
).properties(
    width=800,
    height=300
)
# Out:
# alt.Chart(...)
